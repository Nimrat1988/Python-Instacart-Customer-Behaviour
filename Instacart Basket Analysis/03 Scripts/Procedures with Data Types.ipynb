# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Working with Python data types

# %%
a = 60
b = 40

# %%
a + b
# Out:
# 100

# %%
x =  150
y = 50

# %%
x - y
# Out:
# 100

# %%
c = 70
d = 20

# %%
c + y - d
# Out:
# 100

# %%
# Two floating-point variables

# %%
num1 = 25.5
num2 = 5.1

# %%
#Divide one by the other

# %%
print(num1 / num2)
# Out:
# 5.0

# %%
#Separate strings

# %%
part1 = 'Py'
part2 = 'thon'

# %%
print(part1 + part2)
# Out:
# Python

# %%
#Sentences made of separate strings

# %%
#First sentence
word1 = 'My name'
word2 = 'is Nimrat'

# %%
#Second sentence
word3 = 'I am learning'
word4 = 'Python'

# %%
sentence1 = word1 + ' ' + word2

# %%
sentence2 = word3 + ' ' + word4

# %%
print(sentence1)
print(sentence2)
# Out:
# My name is Nimrat
# I am learning Python

# %%
#Bonus task

# %%
z = 'Hello'

# %%
print(z*100)
# Out:
# ...
